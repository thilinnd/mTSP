# %% [markdown]
# # IMPORT LIBRARIES & DATA

# %%
# %pip install matplotlib numpy pandas

import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve
# Out:
# Requirement already satisfied: matplotlib in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: numpy in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: pillow>=8 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib numpy pandas

import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve
# Out:
# Requirement already satisfied: matplotlib in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: numpy in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: pillow>=8 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
distance_df = pd.read_csv('../data/HN_distance_matrix.csv', index_col=0)
distance_matrix = distance_df.values

# Kiểm tra sơ bộ
print("Số thành phố:", distance_matrix.shape[0])
print("Ví dụ khoảng cách [0][1]:", distance_matrix[0][1])
# Out:
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 21.48

# %%
def detect_convergence(generation_fitness, tolerance=1e-3, window=5):
    for i in range(len(generation_fitness) - window):
        window_values = generation_fitness[i:i+window]
        if max(window_values) - min(window_values) < tolerance:
            return i + window
    return len(generation_fitness)

# %% [markdown]
# # GA + Local search

# %%
for m in range(1, 4):
    print(f"\n=== Số người (m) = {m} ===")
    
    start_time = time.time()
    total_distance, routes, fitness, fitness_per_generation = solve(distance_matrix, m)
    end_time = time.time()

    exec_time = end_time - start_time

    # Tính độ dài từng tuyến để đánh giá
    route_distances = [
        sum(distance_matrix[r[i]][r[i+1]] for i in range(len(r)-1))
        for r in routes
    ]
    max_len = max(route_distances)
    min_len = min(route_distances)
    balance_metric = max_len - min_len

    # Phân tích hội tụ
    converged_gen = detect_convergence(fitness_per_generation)
    convergence_speed = (fitness_per_generation[0] - fitness_per_generation[-1]) / converged_gen if converged_gen else 0

    # In kết quả
    print(f"Tổng quãng đường: {total_distance:.2f}")
    print(f"Tuyến dài nhất (fitness): {fitness:.2f}")
    print(f"Chênh lệch giữa các tuyến (Balance metric): {balance_metric:.2f}")
    print(f"Thời gian thực thi: {exec_time:.4f} giây")
    print(f"Số vòng lặp để hội tụ: {converged_gen}")
    print(f"Tốc độ hội tụ: {convergence_speed:.4f} đơn vị/gen")

    for i, r in enumerate(routes):
        print(f" - Tuyến {i+1} ({route_distances[i]:.2f}): {r}")

    # Vẽ biểu đồ fitness
    plt.figure(figsize=(8, 4))
    plt.plot(fitness_per_generation, marker='o', linestyle='-', color='blue')
    plt.title(f"Fitness qua các thế hệ (m = {m})")
    plt.xlabel("Thế hệ")
    plt.ylabel("Fitness (Tuyến dài nhất)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# === Số người (m) = 1 ===
# Chạy GA (m = 1):   0%|                          | 1/300 [00:01<09:14,  1.85s/it]
# [Gen   0] Best fitness: 1610.65 | Mutation rate: 0.18
# Chạy GA (m = 1):   7%|█▊                       | 22/300 [00:03<00:22, 12.33it/s]
# [Gen  20] Best fitness: 1339.69 | Mutation rate: 0.11
# Chạy GA (m = 1):  14%|███▌                     | 42/300 [00:05<00:19, 13.16it/s]
# [Gen  40] Best fitness: 1222.47 | Mutation rate: 0.12
# Chạy GA (m = 1):  21%|█████▏                   | 62/300 [00:06<00:19, 12.13it/s]
# [Gen  60] Best fitness: 1173.15 | Mutation rate: 0.24
# Chạy GA (m = 1):  27%|██████▊                  | 82/300 [00:08<00:18, 11.79it/s]
# [Gen  80] Best fitness: 1157.59 | Mutation rate: 0.50
# Chạy GA (m = 1):  34%|████████▏               | 102/300 [00:10<00:17, 11.57it/s]
# [Gen 100] Best fitness: 1124.81 | Mutation rate: 0.49
# Chạy GA (m = 1):  41%|█████████▊              | 122/300 [00:12<00:14, 11.88it/s]
# [Gen 120] Best fitness: 1092.50 | Mutation rate: 0.50
# Chạy GA (m = 1):  47%|███████████▎            | 142/300 [00:13<00:13, 11.41it/s]
# [Gen 140] Best fitness: 1067.38 | Mutation rate: 0.50
# Chạy GA (m = 1):  54%|████████████▉           | 162/300 [00:15<00:11, 11.52it/s]
# [Gen 160] Best fitness: 1051.74 | Mutation rate: 0.50
# Chạy GA (m = 1):  61%|██████████████▌         | 182/300 [00:17<00:09, 11.95it/s]
# [Gen 180] Best fitness: 1051.74 | Mutation rate: 0.50
# Chạy GA (m = 1):  67%|████████████████▏       | 202/300 [00:19<00:08, 11.47it/s]
# [Gen 200] Best fitness: 1032.33 | Mutation rate: 0.50
# Chạy GA (m = 1):  74%|█████████████████▊      | 222/300 [00:20<00:07, 10.45it/s]
# [Gen 220] Best fitness: 983.99 | Mutation rate: 0.45
# Chạy GA (m = 1):  81%|███████████████████▎    | 242/300 [00:22<00:05, 11.25it/s]
# [Gen 240] Best fitness: 974.86 | Mutation rate: 0.50
# Chạy GA (m = 1):  87%|████████████████████▉   | 262/300 [00:24<00:03, 11.22it/s]
# [Gen 260] Best fitness: 969.95 | Mutation rate: 0.49
# Chạy GA (m = 1):  94%|██████████████████████▌ | 282/300 [00:26<00:01, 11.67it/s]
# [Gen 280] Best fitness: 916.96 | Mutation rate: 0.50
# Chạy GA (m = 1): 100%|████████████████████████| 300/300 [00:27<00:00, 10.77it/s]
# [Gen 299] Best fitness: 875.75 | Mutation rate: 0.41
# Tổng quãng đường: 875.75
# Tuyến dài nhất (fitness): 875.75
# Chênh lệch giữa các tuyến (Balance metric): 0.00
# Thời gian thực thi: 27.9889 giây
# Số vòng lặp để hội tụ: 37
# Tốc độ hội tụ: 19.8622 đơn vị/gen
#  - Tuyến 1 (875.75): [0, 126, 124, 34, 105, 21, 120, 85, 83, 115, 106, 61, 68, 93, 100, 121, 125, 32, 28, 36, 117, 107, 109, 11, 42, 4, 2, 52, 43, 44, 64, 108, 110, 99, 118, 25, 29, 89, 88, 90, 20, 71, 50, 10, 7, 63, 13, 86, 78, 91, 75, 81, 3, 55, 74, 9, 72, 67, 5, 84, 82, 56, 59, 46, 8, 70, 22, 31, 114, 33, 66, 54, 45, 53, 60, 57, 49, 1, 58, 41, 17, 6, 12, 79, 80, 77, 14, 101, 113, 76, 24, 30, 103, 94, 98, 104, 116, 26, 18, 87, 23, 97, 102, 92, 47, 48, 65, 15, 69, 62, 96, 112, 111, 27, 35, 122, 39, 38, 37, 123, 119, 40, 95, 51, 73, 16, 19, 0]
# === Số người (m) = 2 ===
# Chạy GA (m = 2):   0%|                          | 1/300 [00:00<00:32,  9.24it/s]
# [Gen   0] Best fitness: 851.61 | Mutation rate: 0.18
# Chạy GA (m = 2):   8%|█▉                       | 23/300 [00:01<00:23, 11.68it/s]
# [Gen  20] Best fitness: 743.47 | Mutation rate: 0.13
# Chạy GA (m = 2):  14%|███▌                     | 43/300 [00:03<00:25,  9.94it/s]
# [Gen  40] Best fitness: 708.66 | Mutation rate: 0.27
# Chạy GA (m = 2):  21%|█████▎                   | 63/300 [00:05<00:22, 10.66it/s]
# [Gen  60] Best fitness: 687.03 | Mutation rate: 0.50
# Chạy GA (m = 2):  28%|██████▉                  | 83/300 [00:07<00:18, 11.68it/s]
# [Gen  80] Best fitness: 671.88 | Mutation rate: 0.50
# Chạy GA (m = 2):  34%|████████▏               | 103/300 [00:09<00:15, 12.45it/s]
# [Gen 100] Best fitness: 633.98 | Mutation rate: 0.50
# Chạy GA (m = 2):  40%|█████████▋              | 121/300 [00:10<00:15, 11.43it/s]
# [Gen 120] Best fitness: 620.09 | Mutation rate: 0.50
# Chạy GA (m = 2):  48%|███████████▍            | 143/300 [00:12<00:13, 12.01it/s]
# [Gen 140] Best fitness: 610.06 | Mutation rate: 0.50
# Chạy GA (m = 2):  54%|████████████▉           | 162/300 [00:14<00:14,  9.61it/s]
# [Gen 160] Best fitness: 581.37 | Mutation rate: 0.40
# Chạy GA (m = 2):  60%|██████████████▍         | 181/300 [00:17<00:18,  6.57it/s]
# [Gen 180] Best fitness: 581.37 | Mutation rate: 0.50
# Chạy GA (m = 2):  67%|████████████████▏       | 202/300 [00:19<00:08, 10.92it/s]
# [Gen 200] Best fitness: 573.42 | Mutation rate: 0.50
# Chạy GA (m = 2):  74%|█████████████████▊      | 222/300 [00:21<00:06, 11.63it/s]
# [Gen 220] Best fitness: 566.15 | Mutation rate: 0.50
# Chạy GA (m = 2):  81%|███████████████████▎    | 242/300 [00:23<00:04, 12.33it/s]
# [Gen 240] Best fitness: 566.15 | Mutation rate: 0.50
# Chạy GA (m = 2):  87%|████████████████████▉   | 262/300 [00:24<00:03, 11.66it/s]
# [Gen 260] Best fitness: 566.15 | Mutation rate: 0.50
# Chạy GA (m = 2):  94%|██████████████████████▌ | 282/300 [00:26<00:01, 11.01it/s]
# [Gen 280] Best fitness: 566.15 | Mutation rate: 0.50
# Chạy GA (m = 2): 100%|████████████████████████| 300/300 [00:28<00:00, 10.53it/s]
# [Gen 299] Best fitness: 550.48 | Mutation rate: 0.50
# Tổng quãng đường: 1099.24
# Tuyến dài nhất (fitness): 550.48
# Chênh lệch giữa các tuyến (Balance metric): 1.72
# Thời gian thực thi: 28.7715 giây
# Số vòng lặp để hội tụ: 21
# Tốc độ hội tụ: 14.3395 đơn vị/gen
#  - Tuyến 1 (548.76): [0, 126, 40, 124, 119, 37, 123, 38, 117, 115, 11, 74, 21, 34, 120, 27, 64, 52, 66, 113, 96, 105, 73, 26, 58, 24, 62, 54, 80, 86, 79, 2, 118, 97, 65, 71, 63, 46, 47, 7, 3, 69, 77, 48, 78, 6, 81, 70, 10, 88, 87, 76, 92, 15, 43, 14, 49, 61, 44, 93, 31, 23, 102, 95, 0]
#  - Tuyến 2 (550.48): [0, 83, 29, 104, 103, 100, 13, 112, 111, 35, 101, 85, 109, 106, 98, 114, 51, 9, 25, 17, 28, 4, 5, 67, 91, 45, 1, 53, 72, 94, 110, 30, 20, 56, 33, 22, 68, 8, 59, 50, 57, 60, 55, 89, 116, 99, 75, 12, 90, 18, 121, 32, 122, 108, 125, 36, 39, 107, 84, 82, 41, 42, 16, 19, 0]
# === Số người (m) = 3 ===
# Chạy GA (m = 3):   1%|▏                         | 2/300 [00:00<00:25, 11.71it/s]
# [Gen   0] Best fitness: 603.89 | Mutation rate: 0.18
# Chạy GA (m = 3):   7%|█▊                       | 22/300 [00:01<00:24, 11.44it/s]
# [Gen  20] Best fitness: 538.62 | Mutation rate: 0.36
# Chạy GA (m = 3):  14%|███▌                     | 42/300 [00:03<00:22, 11.70it/s]
# [Gen  40] Best fitness: 538.33 | Mutation rate: 0.50
# Chạy GA (m = 3):  21%|█████▏                   | 62/300 [00:05<00:20, 11.75it/s]
# [Gen  60] Best fitness: 518.56 | Mutation rate: 0.45
# Chạy GA (m = 3):  27%|██████▊                  | 82/300 [00:07<00:18, 12.01it/s]
# [Gen  80] Best fitness: 479.18 | Mutation rate: 0.50
# Chạy GA (m = 3):  34%|████████▏               | 102/300 [00:08<00:16, 11.86it/s]
# [Gen 100] Best fitness: 479.18 | Mutation rate: 0.50
# Chạy GA (m = 3):  41%|█████████▊              | 122/300 [00:10<00:15, 11.44it/s]
# [Gen 120] Best fitness: 468.21 | Mutation rate: 0.50
# Chạy GA (m = 3):  47%|███████████▎            | 142/300 [00:12<00:13, 11.63it/s]
# [Gen 140] Best fitness: 458.43 | Mutation rate: 0.50
# Chạy GA (m = 3):  54%|████████████▉           | 162/300 [00:14<00:11, 11.77it/s]
# [Gen 160] Best fitness: 450.73 | Mutation rate: 0.50
# Chạy GA (m = 3):  61%|██████████████▌         | 182/300 [00:15<00:09, 11.98it/s]
# [Gen 180] Best fitness: 447.22 | Mutation rate: 0.50
# Chạy GA (m = 3):  67%|████████████████▏       | 202/300 [00:17<00:09, 10.26it/s]
# [Gen 200] Best fitness: 445.49 | Mutation rate: 0.50
# Chạy GA (m = 3):  74%|█████████████████▊      | 223/300 [00:19<00:06, 11.70it/s]
# [Gen 220] Best fitness: 435.31 | Mutation rate: 0.36
# Chạy GA (m = 3):  81%|███████████████████▍    | 243/300 [00:21<00:04, 12.17it/s]
# [Gen 240] Best fitness: 430.45 | Mutation rate: 0.50
# Chạy GA (m = 3):  88%|█████████████████████   | 263/300 [00:22<00:03, 11.44it/s]
# [Gen 260] Best fitness: 421.23 | Mutation rate: 0.50
# Chạy GA (m = 3):  94%|██████████████████████▋ | 283/300 [00:24<00:01, 11.99it/s]
# [Gen 280] Best fitness: 420.98 | Mutation rate: 0.50
# Chạy GA (m = 3): 100%|████████████████████████| 300/300 [00:26<00:00, 11.48it/s]
# [Gen 299] Best fitness: 414.15 | Mutation rate: 0.50
# Tổng quãng đường: 1234.55
# Tuyến dài nhất (fitness): 414.15
# Chênh lệch giữa các tuyến (Balance metric): 4.11
# Thời gian thực thi: 26.5634 giây
# Số vòng lặp để hội tụ: 16
# Tốc độ hội tụ: 11.8588 đơn vị/gen
#  - Tuyến 1 (411.34): [0, 124, 126, 82, 84, 95, 51, 60, 10, 79, 88, 112, 113, 48, 62, 9, 86, 70, 85, 53, 72, 80, 64, 7, 67, 99, 34, 120, 73, 92, 102, 24, 35, 33, 89, 29, 27, 110, 36, 98, 54, 69, 43, 49, 0]
#  - Tuyến 2 (409.55): [0, 13, 11, 39, 31, 107, 83, 66, 4, 17, 26, 20, 63, 101, 6, 68, 87, 8, 14, 22, 56, 1, 15, 28, 123, 37, 100, 122, 121, 111, 104, 93, 90, 45, 23, 57, 52, 108, 97, 12, 2, 44, 91, 0]
#  - Tuyến 3 (413.66): [0, 32, 106, 71, 77, 47, 5, 61, 25, 30, 114, 116, 118, 125, 59, 58, 109, 75, 74, 117, 96, 81, 3, 103, 94, 76, 55, 50, 42, 41, 65, 19, 16, 105, 21, 18, 78, 46, 115, 40, 119, 38, 0]

# %% [markdown]
# # GASA

# %% [markdown]
# # RLGA

# %% [markdown]
# # NSGA II
