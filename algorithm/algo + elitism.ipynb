# %% [markdown]
# # IMPORT LIBRARIES & DATA

# %%
# %pip install matplotlib numpy pandas

import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve
# Out:
# Requirement already satisfied: matplotlib in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: numpy in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
distance_df = pd.read_csv('../data/HN_distance_matrix.csv', index_col=0)
distance_matrix = distance_df.values

# Kiểm tra sơ bộ
print("Số thành phố:", distance_matrix.shape[0])
print("Ví dụ khoảng cách [0][1]:", distance_matrix[0][1])
# Out:
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 21.48

# %%
def detect_convergence(generation_fitness, tolerance=1e-3, window=5):
    for i in range(len(generation_fitness) - window):
        window_values = generation_fitness[i:i+window]
        if max(window_values) - min(window_values) < tolerance:
            return i + window
    return len(generation_fitness)

# %% [markdown]
# # GA + Local search

# %%
for m in range(1, 4):
    print(f"\n=== Số người (m) = {m} ===")
    
    start_time = time.time()
    total_distance, routes, fitness, fitness_per_generation = solve(distance_matrix, m)
    end_time = time.time()

    exec_time = end_time - start_time

    # Tính độ dài từng tuyến để đánh giá
    route_distances = [
        sum(distance_matrix[r[i]][r[i+1]] for i in range(len(r)-1))
        for r in routes
    ]
    max_len = max(route_distances)
    min_len = min(route_distances)
    balance_metric = max_len - min_len

    # Phân tích hội tụ
    converged_gen = detect_convergence(fitness_per_generation)
    convergence_speed = (fitness_per_generation[0] - fitness_per_generation[-1]) / converged_gen if converged_gen else 0

    # In kết quả
    print(f"Tổng quãng đường: {total_distance:.2f}")
    print(f"Tuyến dài nhất (fitness): {fitness:.2f}")
    print(f"Chênh lệch giữa các tuyến (Balance metric): {balance_metric:.2f}")
    print(f"Thời gian thực thi: {exec_time:.4f} giây")
    print(f"Số vòng lặp để hội tụ: {converged_gen}")
    print(f"Tốc độ hội tụ: {convergence_speed:.4f} đơn vị/gen")

    for i, r in enumerate(routes):
        print(f" - Tuyến {i+1} ({route_distances[i]:.2f}): {r}")

    # Vẽ biểu đồ fitness
    plt.figure(figsize=(8, 4))
    plt.plot(fitness_per_generation, marker='o', linestyle='-', color='blue')
    plt.title(f"Fitness qua các thế hệ (m = {m})")
    plt.xlabel("Thế hệ")
    plt.ylabel("Fitness (Tuyến dài nhất)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# === Số người (m) = 1 ===
# Chạy GA (m = 1):   0%|                                  | 0/300 [00:00<?, ?it/s]
# [Gen   0] Best fitness: 1600.69
# Chạy GA (m = 1):   7%|█▊                       | 22/300 [00:03<00:40,  6.78it/s]
# [Gen  20] Best fitness: 1260.94
# Chạy GA (m = 1):  14%|███▍                     | 41/300 [00:05<00:29,  8.82it/s]
# [Gen  40] Best fitness: 1208.37
# Chạy GA (m = 1):  21%|█████▏                   | 62/300 [00:07<00:26,  8.88it/s]
# [Gen  60] Best fitness: 1154.84
# Chạy GA (m = 1):  27%|██████▊                  | 82/300 [00:09<00:24,  8.83it/s]
# [Gen  80] Best fitness: 1120.64
# Chạy GA (m = 1):  34%|████████▏               | 102/300 [00:12<00:21,  9.24it/s]
# [Gen 100] Best fitness: 1087.64
# Chạy GA (m = 1):  40%|█████████▋              | 121/300 [00:13<00:17, 10.33it/s]
# [Gen 120] Best fitness: 1087.64
# Chạy GA (m = 1):  47%|███████████▎            | 141/300 [00:15<00:15, 10.17it/s]
# [Gen 140] Best fitness: 1031.30
# Chạy GA (m = 1):  54%|████████████▉           | 161/300 [00:18<00:14,  9.67it/s]
# [Gen 160] Best fitness: 1022.38
# Chạy GA (m = 1):  61%|██████████████▌         | 182/300 [00:20<00:12,  9.73it/s]
# [Gen 180] Best fitness: 969.52
# Chạy GA (m = 1):  67%|████████████████▏       | 202/300 [00:22<00:11,  8.76it/s]
# [Gen 200] Best fitness: 969.52
# Chạy GA (m = 1):  74%|█████████████████▊      | 222/300 [00:25<00:12,  6.41it/s]
# [Gen 220] Best fitness: 898.63
# Chạy GA (m = 1):  80%|███████████████████▎    | 241/300 [00:27<00:06,  9.74it/s]
# [Gen 240] Best fitness: 854.65
# Chạy GA (m = 1):  87%|████████████████████▉   | 261/300 [00:29<00:03, 10.17it/s]
# [Gen 260] Best fitness: 798.53
# Chạy GA (m = 1):  94%|██████████████████████▌ | 282/300 [00:31<00:02,  8.80it/s]
# [Gen 280] Best fitness: 763.55
# Chạy GA (m = 1): 100%|████████████████████████| 300/300 [00:33<00:00,  8.98it/s]
# [Gen 299] Best fitness: 727.86
# Tổng quãng đường: 727.86
# Tuyến dài nhất (fitness): 727.86
# Chênh lệch giữa các tuyến (Balance metric): 0.00
# Thời gian thực thi: 33.5398 giây
# Số vòng lặp để hội tụ: 31
# Tốc độ hội tụ: 28.1558 đơn vị/gen
#  - Tuyến 1 (727.86): [0, 95, 38, 119, 123, 37, 126, 40, 124, 84, 82, 83, 109, 106, 28, 36, 116, 125, 39, 122, 27, 111, 34, 112, 113, 90, 99, 97, 35, 92, 23, 101, 81, 68, 66, 2, 61, 54, 46, 53, 57, 67, 50, 55, 49, 5, 59, 25, 29, 72, 94, 110, 93, 18, 88, 26, 108, 102, 10, 70, 89, 32, 118, 103, 91, 13, 12, 87, 48, 63, 7, 20, 98, 104, 96, 24, 114, 31, 17, 78, 64, 52, 15, 76, 120, 86, 9, 75, 60, 1, 56, 45, 42, 41, 44, 43, 6, 65, 14, 80, 77, 71, 4, 3, 79, 47, 8, 117, 115, 121, 107, 100, 22, 30, 33, 62, 69, 73, 19, 16, 21, 105, 74, 11, 85, 58, 51, 0]
# === Số người (m) = 2 ===
# Chạy GA (m = 2):   1%|▏                         | 2/300 [00:00<00:25, 11.72it/s]
# [Gen   0] Best fitness: 845.70
# Chạy GA (m = 2):   7%|█▊                       | 22/300 [00:02<00:28,  9.76it/s]
# [Gen  20] Best fitness: 731.43
# Chạy GA (m = 2):  14%|███▌                     | 42/300 [00:04<00:25, 10.07it/s]
# [Gen  40] Best fitness: 709.81
# Chạy GA (m = 2):  21%|█████▏                   | 62/300 [00:07<00:29,  8.07it/s]
# [Gen  60] Best fitness: 680.31
# Chạy GA (m = 2):  27%|██████▊                  | 81/300 [00:09<00:30,  7.16it/s]
# [Gen  80] Best fitness: 645.54
# Chạy GA (m = 2):  34%|████████▏               | 102/300 [00:12<00:23,  8.33it/s]
# [Gen 100] Best fitness: 631.12
# Chạy GA (m = 2):  40%|█████████▋              | 121/300 [00:14<00:22,  8.07it/s]
# [Gen 120] Best fitness: 631.12
# Chạy GA (m = 2):  47%|███████████▎            | 141/300 [00:16<00:17,  9.27it/s]
# [Gen 140] Best fitness: 628.69
# Chạy GA (m = 2):  54%|████████████▉           | 162/300 [00:19<00:16,  8.55it/s]
# [Gen 160] Best fitness: 628.69
# Chạy GA (m = 2):  60%|██████████████▍         | 181/300 [00:21<00:14,  8.14it/s]
# [Gen 180] Best fitness: 614.30
# Chạy GA (m = 2):  67%|████████████████        | 201/300 [00:23<00:13,  7.17it/s]
# [Gen 200] Best fitness: 596.35
# Chạy GA (m = 2):  74%|█████████████████▊      | 222/300 [00:26<00:08,  9.38it/s]
# [Gen 220] Best fitness: 587.65
# Chạy GA (m = 2):  80%|███████████████████▎    | 241/300 [00:28<00:06,  9.74it/s]
# [Gen 240] Best fitness: 579.74
# Chạy GA (m = 2):  87%|████████████████████▉   | 261/300 [00:30<00:04,  9.27it/s]
# [Gen 260] Best fitness: 579.74
# Chạy GA (m = 2):  94%|██████████████████████▍ | 281/300 [00:32<00:01, 10.29it/s]
# [Gen 280] Best fitness: 579.74
# Chạy GA (m = 2): 100%|████████████████████████| 300/300 [00:34<00:00,  8.70it/s]
# [Gen 299] Best fitness: 579.74
# Tổng quãng đường: 1150.43
# Tuyến dài nhất (fitness): 579.74
# Chênh lệch giữa các tuyến (Balance metric): 2.11
# Thời gian thực thi: 34.7328 giây
# Số vòng lặp để hội tụ: 13
# Tốc độ hội tụ: 20.4585 đơn vị/gen
#  - Tuyến 1 (576.27): [0, 124, 40, 126, 37, 21, 16, 102, 120, 73, 34, 49, 104, 107, 83, 2, 47, 48, 65, 90, 8, 116, 63, 54, 3, 61, 77, 79, 81, 108, 93, 18, 64, 17, 56, 15, 62, 80, 88, 32, 7, 6, 51, 118, 36, 115, 33, 91, 97, 25, 69, 20, 113, 112, 86, 99, 96, 98, 111, 13, 70, 78, 27, 0]
#  - Tuyến 2 (574.16): [0, 26, 30, 110, 9, 55, 66, 19, 105, 87, 4, 74, 58, 85, 82, 84, 11, 12, 76, 5, 53, 106, 109, 22, 50, 114, 24, 72, 71, 75, 94, 31, 23, 101, 35, 29, 117, 28, 100, 1, 44, 14, 39, 122, 92, 67, 60, 89, 68, 125, 103, 52, 10, 46, 45, 57, 59, 41, 42, 43, 121, 95, 119, 123, 38, 0]
# === Số người (m) = 3 ===
# Chạy GA (m = 3):   0%|                          | 1/300 [00:00<00:30,  9.83it/s]
# [Gen   0] Best fitness: 597.50
# Chạy GA (m = 3):   7%|█▊                       | 22/300 [00:02<00:27, 10.28it/s]
# [Gen  20] Best fitness: 525.99
# Chạy GA (m = 3):  14%|███▌                     | 42/300 [00:04<00:29,  8.75it/s]
# [Gen  40] Best fitness: 501.63
# Chạy GA (m = 3):  21%|█████▏                   | 62/300 [00:06<00:32,  7.42it/s]
# [Gen  60] Best fitness: 501.63
# Chạy GA (m = 3):  27%|██████▊                  | 82/300 [00:09<00:26,  8.37it/s]
# [Gen  80] Best fitness: 495.75
# Chạy GA (m = 3):  34%|████████▏               | 102/300 [00:11<00:19, 10.00it/s]
# [Gen 100] Best fitness: 479.65
# Chạy GA (m = 3):  40%|█████████▋              | 121/300 [00:13<00:21,  8.43it/s]
# [Gen 120] Best fitness: 479.65
# Chạy GA (m = 3):  47%|███████████▎            | 141/300 [00:16<00:20,  7.75it/s]
# [Gen 140] Best fitness: 477.95
# Chạy GA (m = 3):  54%|█████████████           | 163/300 [00:18<00:12, 10.73it/s]
# [Gen 160] Best fitness: 470.57
# Chạy GA (m = 3):  61%|██████████████▌         | 182/300 [00:20<00:11,  9.84it/s]
# [Gen 180] Best fitness: 470.57
# Chạy GA (m = 3):  67%|████████████████▏       | 202/300 [00:22<00:09,  9.81it/s]
# [Gen 200] Best fitness: 460.62
# Chạy GA (m = 3):  74%|█████████████████▊      | 222/300 [00:24<00:08,  9.30it/s]
# [Gen 220] Best fitness: 460.62
# Chạy GA (m = 3):  81%|███████████████████▎    | 242/300 [00:27<00:07,  8.09it/s]
# [Gen 240] Best fitness: 460.62
# Chạy GA (m = 3):  87%|████████████████████▉   | 262/300 [00:29<00:04,  8.03it/s]
# [Gen 260] Best fitness: 455.06
# Chạy GA (m = 3):  94%|██████████████████████▌ | 282/300 [00:32<00:02,  7.56it/s]
# [Gen 280] Best fitness: 443.99
# Chạy GA (m = 3): 100%|████████████████████████| 300/300 [00:34<00:00,  8.70it/s]
# [Gen 299] Best fitness: 439.92
# Tổng quãng đường: 1319.57
# Tuyến dài nhất (fitness): 439.92
# Chênh lệch giữa các tuyến (Balance metric): 0.14
# Thời gian thực thi: 34.8779 giây
# Số vòng lặp để hội tụ: 15
# Tốc độ hội tụ: 10.5053 đơn vị/gen
#  - Tuyến 1 (439.92): [0, 124, 126, 119, 103, 28, 111, 70, 100, 116, 81, 34, 35, 108, 71, 20, 96, 29, 33, 121, 79, 97, 99, 36, 82, 84, 95, 83, 75, 87, 60, 105, 19, 21, 62, 57, 101, 23, 68, 104, 50, 5, 67, 0]
#  - Tuyến 2 (439.87): [0, 59, 107, 109, 45, 74, 85, 11, 102, 66, 25, 94, 6, 112, 55, 1, 49, 13, 27, 76, 41, 3, 16, 73, 4, 48, 120, 14, 98, 77, 22, 51, 9, 64, 113, 56, 7, 61, 31, 92, 80, 72, 2, 0]
#  - Tuyến 3 (439.78): [0, 53, 46, 93, 32, 10, 15, 37, 118, 39, 17, 86, 24, 18, 88, 30, 78, 125, 110, 89, 54, 12, 8, 114, 117, 52, 65, 47, 43, 58, 91, 90, 42, 44, 26, 63, 106, 69, 122, 115, 123, 38, 40, 0]

# %% [markdown]
# # GASA

# %% [markdown]
# # RLGA

# %% [markdown]
# # NSGA II
