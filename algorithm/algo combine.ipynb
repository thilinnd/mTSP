# %% [markdown]
# # IMPORT LIBRARIES & DATA

# %%
# %pip install matplotlib numpy pandas

import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve
# Out:
# Requirement already satisfied: matplotlib in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: numpy in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: pillow>=8 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib numpy pandas

import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve
# Out:
# Requirement already satisfied: matplotlib in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: numpy in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
distance_df = pd.read_csv('../data/HN_distance_matrix.csv', index_col=0)
distance_matrix = distance_df.values

# Kiểm tra sơ bộ
print("Số thành phố:", distance_matrix.shape[0])
print("Ví dụ khoảng cách [0][1]:", distance_matrix[0][1])
# Out:
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 21.48

# %%
def detect_convergence(generation_fitness, tolerance=1e-3, window=5):
    for i in range(len(generation_fitness) - window):
        window_values = generation_fitness[i:i+window]
        if max(window_values) - min(window_values) < tolerance:
            return i + window
    return len(generation_fitness)

# %% [markdown]
# # GA + Local search

# %%
for m in range(1, 4):
    print(f"\n=== Số người (m) = {m} ===")
    
    start_time = time.time()
    total, routes, best, history = solve(distance_matrix,
    m=m,
    population_size=100,
    generations=300,
    elite_size=2,                 # giữ lại 2 cá thể tốt nhất mỗi thế hệ
    initial_mutation_rate=0.2,    # mutation rate ban đầu
    min_mutation=0.05,
    max_mutation=0.5
)

    end_time = time.time()

    exec_time = end_time - start_time

    # Tính độ dài từng tuyến để đánh giá
    route_distances = [
        sum(distance_matrix[r[i]][r[i+1]] for i in range(len(r)-1))
        for r in routes
    ]
    max_len = max(route_distances)
    min_len = min(route_distances)
    balance_metric = max_len - min_len

    # Phân tích hội tụ
    converged_gen = detect_convergence(history)
    convergence_speed = (history[0] - history[-1]) / converged_gen if converged_gen else 0

    # In kết quả
    print(f"Tổng quãng đường: {total:.2f}")
    print(f"Tuyến dài nhất (fitness): {best:.2f}")
    print(f"Chênh lệch giữa các tuyến (Balance metric): {balance_metric:.2f}")
    print(f"Thời gian thực thi: {exec_time:.4f} giây")
    print(f"Số vòng lặp để hội tụ: {converged_gen}")
    print(f"Tốc độ hội tụ: {convergence_speed:.4f} đơn vị/gen")

    for i, r in enumerate(routes):
        print(f" - Tuyến {i+1} ({route_distances[i]:.2f}): {r}")

    # Vẽ biểu đồ fitness
    plt.figure(figsize=(8, 4))
    plt.plot(history, marker='o', linestyle='-', color='blue')
    plt.title(f"Fitness qua các thế hệ (m = {m})")
    plt.xlabel("Thế hệ")
    plt.ylabel("Fitness (Tuyến dài nhất)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# === Số người (m) = 1 ===
# Chạy GA (m = 1):   1%|▏                         | 2/300 [00:00<00:21, 13.62it/s]
# [Gen   0] Best fitness: 1529.35 | Mutation rate: 0.18
# Chạy GA (m = 1):   8%|██                       | 24/300 [00:01<00:18, 14.95it/s]
# [Gen  20] Best fitness: 1279.24 | Mutation rate: 0.11
# Chạy GA (m = 1):  14%|███▌                     | 43/300 [00:02<00:16, 15.48it/s]
# [Gen  40] Best fitness: 1089.95 | Mutation rate: 0.07
# Chạy GA (m = 1):  21%|█████▎                   | 64/300 [00:04<00:14, 15.81it/s]
# [Gen  60] Best fitness: 1004.41 | Mutation rate: 0.05
# Chạy GA (m = 1):  28%|███████                  | 84/300 [00:05<00:13, 16.17it/s]
# [Gen  80] Best fitness: 946.09 | Mutation rate: 0.06
# Chạy GA (m = 1):  34%|████████▏               | 102/300 [00:06<00:15, 13.13it/s]
# [Gen 100] Best fitness: 890.91 | Mutation rate: 0.05
# Chạy GA (m = 1):  41%|█████████▊              | 122/300 [00:08<00:15, 11.66it/s]
# [Gen 120] Best fitness: 836.73 | Mutation rate: 0.07
# Chạy GA (m = 1):  47%|███████████▎            | 142/300 [00:10<00:14, 10.76it/s]
# [Gen 140] Best fitness: 811.90 | Mutation rate: 0.11
# Chạy GA (m = 1):  54%|████████████▉           | 162/300 [00:11<00:10, 12.73it/s]
# [Gen 160] Best fitness: 764.83 | Mutation rate: 0.06
# Chạy GA (m = 1):  61%|██████████████▋         | 184/300 [00:13<00:08, 13.60it/s]
# [Gen 180] Best fitness: 746.94 | Mutation rate: 0.09
# Chạy GA (m = 1):  67%|████████████████▏       | 202/300 [00:14<00:07, 13.17it/s]
# [Gen 200] Best fitness: 737.20 | Mutation rate: 0.05
# Chạy GA (m = 1):  74%|█████████████████▊      | 222/300 [00:16<00:06, 12.58it/s]
# [Gen 220] Best fitness: 725.32 | Mutation rate: 0.09
# Chạy GA (m = 1):  81%|███████████████████▎    | 242/300 [00:17<00:04, 11.94it/s]
# [Gen 240] Best fitness: 718.06 | Mutation rate: 0.23
# Chạy GA (m = 1):  87%|████████████████████▉   | 262/300 [00:19<00:03,  9.91it/s]
# [Gen 260] Best fitness: 699.95 | Mutation rate: 0.26
# Chạy GA (m = 1):  94%|██████████████████████▌ | 282/300 [00:21<00:01, 13.03it/s]
# [Gen 280] Best fitness: 669.70 | Mutation rate: 0.10
# Chạy GA (m = 1): 100%|████████████████████████| 300/300 [00:23<00:00, 13.03it/s]
# [Gen 299] Best fitness: 646.25 | Mutation rate: 0.09
# Tổng quãng đường: 646.25
# Tuyến dài nhất (fitness): 646.25
# Chênh lệch giữa các tuyến (Balance metric): 0.00
# Thời gian thực thi: 23.1774 giây
# Số vòng lặp để hội tụ: 71
# Tốc độ hội tụ: 12.4380 đơn vị/gen
#  - Tuyến 1 (646.25): [0, 95, 126, 40, 124, 119, 38, 125, 116, 32, 28, 39, 34, 120, 112, 35, 110, 88, 68, 4, 72, 7, 63, 59, 60, 58, 55, 53, 5, 85, 83, 109, 106, 100, 22, 67, 9, 75, 48, 47, 52, 61, 71, 79, 64, 80, 15, 81, 20, 92, 111, 113, 105, 16, 73, 19, 21, 62, 77, 65, 43, 45, 50, 57, 10, 70, 99, 26, 90, 89, 25, 29, 31, 94, 18, 86, 17, 108, 97, 6, 8, 78, 66, 13, 24, 104, 30, 33, 121, 123, 51, 56, 11, 74, 82, 84, 1, 49, 41, 42, 46, 44, 3, 2, 54, 93, 96, 23, 102, 27, 101, 87, 14, 76, 69, 12, 91, 98, 103, 114, 118, 122, 36, 117, 37, 115, 107, 0]
# === Số người (m) = 2 ===
# Chạy GA (m = 2):   1%|▏                         | 2/300 [00:00<00:21, 13.78it/s]
# [Gen   0] Best fitness: 846.74 | Mutation rate: 0.18
# Chạy GA (m = 2):   7%|█▊                       | 22/300 [00:01<00:23, 11.94it/s]
# [Gen  20] Best fitness: 741.07 | Mutation rate: 0.20
# Chạy GA (m = 2):  14%|███▌                     | 42/300 [00:03<00:23, 10.89it/s]
# [Gen  40] Best fitness: 676.15 | Mutation rate: 0.33
# Chạy GA (m = 2):  21%|█████▏                   | 62/300 [00:05<00:20, 11.79it/s]
# [Gen  60] Best fitness: 631.13 | Mutation rate: 0.44
# Chạy GA (m = 2):  27%|██████▊                  | 82/300 [00:07<00:19, 11.34it/s]
# [Gen  80] Best fitness: 591.50 | Mutation rate: 0.50
# Chạy GA (m = 2):  34%|████████▏               | 102/300 [00:08<00:16, 11.66it/s]
# [Gen 100] Best fitness: 581.52 | Mutation rate: 0.50
# Chạy GA (m = 2):  41%|█████████▊              | 122/300 [00:10<00:14, 12.41it/s]
# [Gen 120] Best fitness: 555.83 | Mutation rate: 0.50
# Chạy GA (m = 2):  47%|███████████▎            | 142/300 [00:12<00:15, 10.17it/s]
# [Gen 140] Best fitness: 547.55 | Mutation rate: 0.49
# Chạy GA (m = 2):  54%|████████████▉           | 162/300 [00:14<00:12, 11.33it/s]
# [Gen 160] Best fitness: 540.98 | Mutation rate: 0.45
# Chạy GA (m = 2):  61%|██████████████▌         | 182/300 [00:16<00:11, 10.47it/s]
# [Gen 180] Best fitness: 526.95 | Mutation rate: 0.45
# Chạy GA (m = 2):  68%|████████████████▏       | 203/300 [00:18<00:09, 10.13it/s]
# [Gen 200] Best fitness: 514.48 | Mutation rate: 0.50
# Chạy GA (m = 2):  74%|█████████████████▊      | 223/300 [00:20<00:07, 10.38it/s]
# [Gen 220] Best fitness: 505.33 | Mutation rate: 0.49
# Chạy GA (m = 2):  81%|███████████████████▍    | 243/300 [00:21<00:04, 11.90it/s]
# [Gen 240] Best fitness: 491.60 | Mutation rate: 0.43
# Chạy GA (m = 2):  87%|████████████████████▉   | 261/300 [00:23<00:03,  9.90it/s]
# [Gen 260] Best fitness: 488.37 | Mutation rate: 0.50
# Chạy GA (m = 2):  94%|██████████████████████▋ | 283/300 [00:25<00:01, 12.52it/s]
# [Gen 280] Best fitness: 479.02 | Mutation rate: 0.44
# Chạy GA (m = 2): 100%|████████████████████████| 300/300 [00:26<00:00, 11.13it/s]
# [Gen 299] Best fitness: 466.93 | Mutation rate: 0.50
# Tổng quãng đường: 932.76
# Tuyến dài nhất (fitness): 466.93
# Chênh lệch giữa các tuyến (Balance metric): 1.10
# Thời gian thực thi: 27.2274 giây
# Số vòng lặp để hội tụ: 22
# Tốc độ hội tụ: 17.2641 đơn vị/gen
#  - Tuyến 1 (465.83): [0, 84, 48, 44, 19, 16, 73, 120, 108, 122, 23, 75, 11, 9, 25, 101, 112, 111, 76, 105, 4, 71, 80, 1, 67, 27, 113, 97, 47, 3, 7, 2, 26, 99, 39, 36, 98, 91, 56, 117, 106, 30, 110, 118, 103, 41, 42, 50, 58, 60, 59, 74, 63, 72, 96, 92, 81, 104, 90, 66, 8, 61, 83, 95, 0]
#  - Tuyến 2 (466.93): [0, 43, 54, 46, 45, 49, 52, 93, 78, 69, 14, 18, 88, 24, 13, 5, 53, 57, 55, 10, 20, 86, 35, 29, 28, 115, 38, 123, 107, 121, 125, 114, 32, 31, 94, 89, 65, 68, 79, 12, 77, 6, 64, 17, 102, 87, 15, 34, 21, 62, 116, 22, 85, 82, 51, 100, 33, 109, 119, 40, 126, 124, 37, 70, 0]
# === Số người (m) = 3 ===
# Chạy GA (m = 3):   1%|▏                         | 2/300 [00:00<00:27, 10.98it/s]
# [Gen   0] Best fitness: 617.83 | Mutation rate: 0.18
# Chạy GA (m = 3):   7%|█▊                       | 22/300 [00:01<00:21, 12.80it/s]
# [Gen  20] Best fitness: 529.12 | Mutation rate: 0.20
# Chạy GA (m = 3):  14%|███▌                     | 42/300 [00:03<00:22, 11.59it/s]
# [Gen  40] Best fitness: 468.91 | Mutation rate: 0.27
# Chạy GA (m = 3):  21%|█████▏                   | 62/300 [00:05<00:21, 11.09it/s]
# [Gen  60] Best fitness: 444.35 | Mutation rate: 0.50
# Chạy GA (m = 3):  27%|██████▊                  | 82/300 [00:07<00:18, 11.48it/s]
# [Gen  80] Best fitness: 430.65 | Mutation rate: 0.50
# Chạy GA (m = 3):  34%|████████▏               | 102/300 [00:08<00:16, 11.78it/s]
# [Gen 100] Best fitness: 405.53 | Mutation rate: 0.31
# Chạy GA (m = 3):  41%|█████████▊              | 122/300 [00:10<00:15, 11.55it/s]
# [Gen 120] Best fitness: 396.28 | Mutation rate: 0.50
# Chạy GA (m = 3):  47%|███████████▎            | 142/300 [00:12<00:14, 10.68it/s]
# [Gen 140] Best fitness: 385.62 | Mutation rate: 0.50
# Chạy GA (m = 3):  54%|████████████▉           | 162/300 [00:14<00:12, 10.94it/s]
# [Gen 160] Best fitness: 380.42 | Mutation rate: 0.50
# Chạy GA (m = 3):  61%|██████████████▌         | 182/300 [00:16<00:10, 11.40it/s]
# [Gen 180] Best fitness: 363.92 | Mutation rate: 0.50
# Chạy GA (m = 3):  67%|████████████████▏       | 202/300 [00:17<00:07, 12.38it/s]
# [Gen 200] Best fitness: 350.98 | Mutation rate: 0.28
# Chạy GA (m = 3):  74%|█████████████████▊      | 222/300 [00:19<00:06, 11.64it/s]
# [Gen 220] Best fitness: 341.07 | Mutation rate: 0.26
# Chạy GA (m = 3):  81%|███████████████████▎    | 242/300 [00:21<00:04, 12.35it/s]
# [Gen 240] Best fitness: 332.28 | Mutation rate: 0.28
# Chạy GA (m = 3):  87%|████████████████████▉   | 262/300 [00:22<00:03, 12.51it/s]
# [Gen 260] Best fitness: 327.63 | Mutation rate: 0.38
# Chạy GA (m = 3):  94%|██████████████████████▌ | 282/300 [00:24<00:01, 11.58it/s]
# [Gen 280] Best fitness: 321.64 | Mutation rate: 0.48
# Chạy GA (m = 3): 100%|████████████████████████| 300/300 [00:26<00:00, 11.47it/s]
# [Gen 299] Best fitness: 318.44 | Mutation rate: 0.50
# Tổng quãng đường: 953.57
# Tuyến dài nhất (fitness): 318.44
# Chênh lệch giữa các tuyến (Balance metric): 1.47
# Thời gian thực thi: 26.6011 giây
# Số vòng lặp để hội tụ: 19
# Tốc độ hội tụ: 15.7574 đơn vị/gen
#  - Tuyến 1 (316.97): [0, 40, 126, 38, 21, 19, 45, 46, 54, 41, 42, 50, 49, 57, 16, 105, 34, 15, 98, 103, 29, 31, 94, 18, 13, 26, 110, 62, 14, 69, 80, 64, 79, 17, 93, 86, 70, 72, 67, 5, 92, 81, 78, 0]
#  - Tuyến 2 (318.44): [0, 27, 111, 120, 23, 97, 102, 122, 116, 22, 75, 52, 68, 47, 65, 71, 77, 91, 89, 104, 25, 90, 59, 1, 55, 11, 9, 88, 117, 37, 107, 74, 7, 63, 12, 48, 35, 24, 118, 125, 39, 115, 124, 0]
#  - Tuyến 3 (318.16): [0, 84, 36, 106, 28, 109, 53, 10, 51, 56, 60, 58, 85, 83, 2, 3, 61, 66, 4, 76, 87, 101, 108, 20, 8, 32, 30, 33, 100, 114, 99, 96, 44, 43, 6, 73, 112, 113, 95, 119, 123, 121, 82, 0]

# %% [markdown]
# # GASA

# %% [markdown]
# # RLGA

# %% [markdown]
# # NSGA II
