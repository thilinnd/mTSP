# %% [markdown]
# # IMPORT LIBRARIES & DATA

# %%
import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve

import random

# %%
distance_df = pd.read_csv('../data/HN_distance_matrix.csv', index_col=0)
distance_matrix = distance_df.values

# Kiểm tra sơ bộ
print("Số thành phố:", distance_matrix.shape[0])
print("Ví dụ khoảng cách [0][1]:", distance_matrix[0][1])
# Out:
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 21.48

# %%
def detect_convergence(generation_fitness, tolerance=1e-3, window=5):
    for i in range(len(generation_fitness) - window):
        window_values = generation_fitness[i:i+window]
        if max(window_values) - min(window_values) < tolerance:
            return i + window
    return len(generation_fitness)

# %% [markdown]
# # GA + Local search

# %%
for m in range(1, 4):
    print(f"\n=== Số người (m) = {m} ===")
    
    start_time = time.time()
    total_distance, routes, fitness, fitness_per_generation = solve(distance_matrix, m)
    end_time = time.time()

    exec_time = end_time - start_time

    # Tính độ dài từng tuyến để đánh giá
    route_distances = [
        sum(distance_matrix[r[i]][r[i+1]] for i in range(len(r)-1))
        for r in routes
    ]
    max_len = max(route_distances)
    min_len = min(route_distances)
    balance_metric = max_len - min_len

    # Phân tích hội tụ
    converged_gen = detect_convergence(fitness_per_generation)
    convergence_speed = (fitness_per_generation[0] - fitness_per_generation[-1]) / converged_gen if converged_gen else 0

    # In kết quả
    print(f"Tổng quãng đường: {total_distance:.2f}")
    print(f"Tuyến dài nhất (fitness): {fitness:.2f}")
    print(f"Chênh lệch giữa các tuyến (Balance metric): {balance_metric:.2f}")
    print(f"Thời gian thực thi: {exec_time:.4f} giây")
    print(f"Số vòng lặp để hội tụ: {converged_gen}")
    print(f"Tốc độ hội tụ: {convergence_speed:.4f} đơn vị/gen")

    for i, r in enumerate(routes):
        print(f" - Tuyến {i+1} ({route_distances[i]:.2f}): {r}")

    # Vẽ biểu đồ fitness
    plt.figure(figsize=(8, 4))
    plt.plot(fitness_per_generation, marker='o', linestyle='-', color='blue')
    plt.title(f"Fitness qua các thế hệ (m = {m})")
    plt.xlabel("Thế hệ")
    plt.ylabel("Fitness (Tuyến dài nhất)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# === Số người (m) = 1 ===
# Chạy GA (m = 1):   0%|                                  | 0/300 [00:00<?, ?it/s]
# Chạy GA (m = 1):   1%|▏                         | 2/300 [00:01<03:46,  1.32it/s]
# [Gen   0] Best fitness: 1606.55 | Mutation rate: 0.18
# Chạy GA (m = 1):   8%|█▉                       | 23/300 [00:03<00:21, 13.09it/s]
# [Gen  20] Best fitness: 1255.95 | Mutation rate: 0.07
# Chạy GA (m = 1):  14%|███▌                     | 43/300 [00:05<00:18, 13.75it/s]
# [Gen  40] Best fitness: 1107.32 | Mutation rate: 0.05
# Chạy GA (m = 1):  21%|█████▎                   | 63/300 [00:06<00:15, 15.69it/s]
# [Gen  60] Best fitness: 971.89 | Mutation rate: 0.06
# Chạy GA (m = 1):  28%|██████▉                  | 83/300 [00:07<00:14, 14.84it/s]
# [Gen  80] Best fitness: 870.24 | Mutation rate: 0.06
# Chạy GA (m = 1):  34%|████████▏               | 103/300 [00:09<00:13, 14.95it/s]
# [Gen 100] Best fitness: 825.85 | Mutation rate: 0.05
# Chạy GA (m = 1):  41%|█████████▊              | 123/300 [00:10<00:13, 13.53it/s]
# [Gen 120] Best fitness: 795.89 | Mutation rate: 0.05
# Chạy GA (m = 1):  48%|███████████▍            | 143/300 [00:12<00:11, 13.45it/s]
# [Gen 140] Best fitness: 782.84 | Mutation rate: 0.06
# Chạy GA (m = 1):  54%|████████████▉           | 161/300 [00:13<00:12, 11.14it/s]
# [Gen 160] Best fitness: 744.99 | Mutation rate: 0.07
# Chạy GA (m = 1):  61%|██████████████▌         | 182/300 [00:15<00:11, 10.71it/s]
# [Gen 180] Best fitness: 726.07 | Mutation rate: 0.05
# Chạy GA (m = 1):  68%|████████████████▎       | 204/300 [00:17<00:06, 13.95it/s]
# [Gen 200] Best fitness: 714.83 | Mutation rate: 0.11
# Chạy GA (m = 1):  75%|█████████████████▉      | 224/300 [00:18<00:05, 13.73it/s]
# [Gen 220] Best fitness: 696.18 | Mutation rate: 0.07
# Chạy GA (m = 1):  81%|███████████████████▎    | 242/300 [00:20<00:04, 14.28it/s]
# [Gen 240] Best fitness: 677.64 | Mutation rate: 0.05
# Chạy GA (m = 1):  88%|█████████████████████   | 264/300 [00:21<00:02, 15.48it/s]
# [Gen 260] Best fitness: 665.84 | Mutation rate: 0.10
# Chạy GA (m = 1):  95%|██████████████████████▋ | 284/300 [00:23<00:01, 15.21it/s]
# [Gen 280] Best fitness: 656.34 | Mutation rate: 0.14
# Chạy GA (m = 1): 100%|████████████████████████| 300/300 [00:24<00:00, 12.45it/s]
# [Gen 299] Best fitness: 649.34 | Mutation rate: 0.17
# Tổng quãng đường: 649.34
# Tuyến dài nhất (fitness): 649.34
# Chênh lệch giữa các tuyến (Balance metric): 0.00
# Thời gian thực thi: 24.2707 giây
# Số vòng lặp để hội tụ: 135
# Tốc độ hội tụ: 7.0904 đơn vị/gen
#  - Tuyến 1 (649.34): [0, 41, 42, 56, 58, 85, 107, 109, 90, 12, 47, 64, 65, 6, 62, 76, 57, 60, 51, 83, 1, 50, 53, 49, 10, 24, 20, 86, 89, 75, 52, 2, 63, 13, 88, 93, 23, 97, 92, 77, 79, 61, 8, 7, 72, 59, 9, 67, 110, 122, 35, 108, 26, 96, 25, 103, 30, 114, 104, 18, 81, 71, 87, 15, 43, 44, 3, 70, 74, 82, 119, 123, 121, 37, 38, 106, 22, 98, 94, 68, 4, 48, 69, 80, 14, 17, 78, 66, 54, 45, 46, 5, 55, 11, 117, 115, 33, 29, 32, 31, 118, 116, 27, 34, 21, 16, 73, 19, 105, 120, 113, 112, 111, 101, 102, 99, 91, 100, 28, 36, 39, 125, 84, 95, 124, 126, 40, 0]
# === Số người (m) = 2 ===
# Chạy GA (m = 2):   0%|                          | 1/300 [00:00<00:36,  8.19it/s]
# [Gen   0] Best fitness: 847.75 | Mutation rate: 0.18
# Chạy GA (m = 2):   7%|█▊                       | 22/300 [00:01<00:19, 14.07it/s]
# [Gen  20] Best fitness: 732.49 | Mutation rate: 0.13
# Chạy GA (m = 2):  14%|███▌                     | 42/300 [00:03<00:19, 13.27it/s]
# [Gen  40] Best fitness: 670.52 | Mutation rate: 0.18
# Chạy GA (m = 2):  21%|█████▏                   | 62/300 [00:04<00:20, 11.71it/s]
# [Gen  60] Best fitness: 647.45 | Mutation rate: 0.36
# Chạy GA (m = 2):  27%|██████▊                  | 82/300 [00:07<00:28,  7.56it/s]
# [Gen  80] Best fitness: 607.59 | Mutation rate: 0.50
# Chạy GA (m = 2):  34%|████████▏               | 103/300 [00:10<00:20,  9.85it/s]
# [Gen 100] Best fitness: 585.34 | Mutation rate: 0.50
# Chạy GA (m = 2):  41%|█████████▊              | 123/300 [00:11<00:15, 11.15it/s]
# [Gen 120] Best fitness: 549.95 | Mutation rate: 0.45
# Chạy GA (m = 2):  47%|███████████▎            | 142/300 [00:14<00:16,  9.55it/s]
# [Gen 140] Best fitness: 529.05 | Mutation rate: 0.50
# Chạy GA (m = 2):  54%|████████████▉           | 162/300 [00:16<00:12, 10.64it/s]
# [Gen 160] Best fitness: 518.38 | Mutation rate: 0.50
# Chạy GA (m = 2):  61%|██████████████▋         | 183/300 [00:18<00:10, 11.30it/s]
# [Gen 180] Best fitness: 494.25 | Mutation rate: 0.45
# Chạy GA (m = 2):  68%|████████████████▏       | 203/300 [00:19<00:08, 11.62it/s]
# [Gen 200] Best fitness: 473.93 | Mutation rate: 0.50
# Chạy GA (m = 2):  74%|█████████████████▋      | 221/300 [00:21<00:07, 10.14it/s]
# [Gen 220] Best fitness: 459.66 | Mutation rate: 0.50
# Chạy GA (m = 2):  81%|███████████████████▍    | 243/300 [00:23<00:05, 11.23it/s]
# [Gen 240] Best fitness: 445.53 | Mutation rate: 0.43
# Chạy GA (m = 2):  88%|█████████████████████   | 263/300 [00:25<00:02, 12.98it/s]
# [Gen 260] Best fitness: 426.84 | Mutation rate: 0.32
# Chạy GA (m = 2):  94%|██████████████████████▌ | 282/300 [00:26<00:01, 10.88it/s]
# [Gen 280] Best fitness: 418.93 | Mutation rate: 0.50
# Chạy GA (m = 2): 100%|████████████████████████| 300/300 [00:28<00:00, 10.52it/s]
# [Gen 299] Best fitness: 413.93 | Mutation rate: 0.45
# Tổng quãng đường: 823.62
# Tuyến dài nhất (fitness): 413.93
# Chênh lệch giữa các tuyến (Balance metric): 4.24
# Thời gian thực thi: 28.8031 giây
# Số vòng lặp để hội tụ: 32
# Tốc độ hội tụ: 13.5569 đơn vị/gen
#  - Tuyến 1 (409.69): [0, 74, 121, 123, 124, 40, 119, 37, 22, 125, 36, 39, 111, 112, 14, 92, 79, 81, 12, 15, 73, 16, 19, 120, 62, 87, 98, 24, 102, 35, 108, 91, 13, 75, 3, 54, 52, 43, 47, 44, 77, 65, 8, 61, 66, 63, 78, 18, 26, 94, 59, 2, 68, 71, 64, 6, 21, 105, 27, 99, 89, 51, 82, 84, 0]
#  - Tuyến 2 (413.93): [0, 1, 60, 55, 5, 114, 117, 107, 115, 28, 106, 30, 33, 103, 25, 118, 104, 7, 72, 31, 10, 76, 69, 80, 23, 101, 97, 17, 96, 93, 20, 90, 29, 32, 9, 86, 88, 70, 11, 83, 109, 100, 85, 56, 50, 42, 46, 53, 57, 45, 49, 41, 4, 48, 113, 34, 110, 116, 122, 67, 58, 95, 38, 126, 0]
# === Số người (m) = 3 ===
# Chạy GA (m = 3):   1%|▏                         | 2/300 [00:00<00:26, 11.35it/s]
# [Gen   0] Best fitness: 599.18 | Mutation rate: 0.18
# Chạy GA (m = 3):   7%|█▊                       | 22/300 [00:01<00:21, 13.18it/s]
# [Gen  20] Best fitness: 510.81 | Mutation rate: 0.09
# Chạy GA (m = 3):  14%|███▌                     | 42/300 [00:03<00:24, 10.39it/s]
# [Gen  40] Best fitness: 490.89 | Mutation rate: 0.33
# Chạy GA (m = 3):  21%|█████▎                   | 63/300 [00:05<00:19, 12.34it/s]
# [Gen  60] Best fitness: 483.53 | Mutation rate: 0.50
# Chạy GA (m = 3):  28%|██████▉                  | 83/300 [00:06<00:17, 12.23it/s]
# [Gen  80] Best fitness: 443.98 | Mutation rate: 0.43
# Chạy GA (m = 3):  34%|████████▏               | 103/300 [00:08<00:15, 12.43it/s]
# [Gen 100] Best fitness: 443.67 | Mutation rate: 0.50
# Chạy GA (m = 3):  41%|█████████▊              | 123/300 [00:10<00:14, 12.56it/s]
# [Gen 120] Best fitness: 428.74 | Mutation rate: 0.45
# Chạy GA (m = 3):  48%|███████████▍            | 143/300 [00:12<00:14, 10.71it/s]
# [Gen 140] Best fitness: 416.95 | Mutation rate: 0.45
# Chạy GA (m = 3):  54%|█████████████           | 163/300 [00:13<00:11, 12.14it/s]
# [Gen 160] Best fitness: 411.81 | Mutation rate: 0.49
# Chạy GA (m = 3):  61%|██████████████▌         | 182/300 [00:16<00:10, 11.71it/s]
# [Gen 180] Best fitness: 393.72 | Mutation rate: 0.50
# Chạy GA (m = 3):  68%|████████████████▎       | 204/300 [00:17<00:07, 13.18it/s]
# [Gen 200] Best fitness: 381.61 | Mutation rate: 0.41
# Chạy GA (m = 3):  74%|█████████████████▊      | 222/300 [00:19<00:05, 14.29it/s]
# [Gen 220] Best fitness: 365.28 | Mutation rate: 0.30
# Chạy GA (m = 3):  81%|███████████████████▎    | 242/300 [00:20<00:04, 13.01it/s]
# [Gen 240] Best fitness: 347.44 | Mutation rate: 0.22
# Chạy GA (m = 3):  87%|████████████████████▉   | 262/300 [00:22<00:03, 11.37it/s]
# [Gen 260] Best fitness: 330.82 | Mutation rate: 0.25
# Chạy GA (m = 3):  94%|██████████████████████▍ | 281/300 [00:24<00:02,  6.75it/s]
# [Gen 280] Best fitness: 324.15 | Mutation rate: 0.40
# Chạy GA (m = 3): 100%|████████████████████████| 300/300 [00:28<00:00, 10.52it/s]
# [Gen 299] Best fitness: 314.75 | Mutation rate: 0.44
# Tổng quãng đường: 943.39
# Tuyến dài nhất (fitness): 314.75
# Chênh lệch giữa các tuyến (Balance metric): 0.85
# Thời gian thực thi: 29.4549 giây
# Số vòng lặp để hội tụ: 24
# Tốc độ hội tụ: 11.8513 đơn vị/gen
#  - Tuyến 1 (314.75): [0, 38, 37, 33, 32, 114, 8, 73, 16, 120, 112, 65, 64, 43, 47, 72, 10, 84, 82, 70, 78, 68, 71, 69, 62, 15, 101, 23, 26, 63, 3, 52, 48, 44, 66, 24, 28, 36, 125, 116, 22, 74, 58, 0]
#  - Tuyến 2 (314.74): [0, 42, 54, 6, 34, 105, 87, 13, 75, 98, 29, 118, 99, 113, 111, 92, 76, 14, 4, 94, 12, 90, 89, 110, 108, 122, 39, 107, 60, 51, 56, 117, 121, 123, 104, 103, 96, 81, 77, 80, 97, 19, 21, 0]
#  - Tuyến 3 (313.90): [0, 7, 115, 106, 18, 88, 17, 79, 20, 25, 31, 35, 27, 102, 93, 86, 91, 119, 40, 126, 124, 95, 85, 1, 45, 2, 61, 30, 100, 5, 49, 41, 57, 67, 9, 59, 55, 50, 46, 83, 109, 11, 53, 0]

# %% [markdown]
# # GASA

# %% [markdown]
# # RLGA

# %% [markdown]
# # NSGA II
