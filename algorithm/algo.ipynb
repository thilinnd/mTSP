# %% [markdown]
# # IMPORT LIBRARIES & DATA

# %%
import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve

import random

# %%
distance_df = pd.read_csv('../data/HN_distance_matrix.csv', index_col=0)
distance_matrix = distance_df.values

# Kiểm tra sơ bộ
print("Số thành phố:", distance_matrix.shape[0])
print("Ví dụ khoảng cách [0][1]:", distance_matrix[0][1])
# Out:
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 21.48

# %%
def detect_convergence(generation_fitness, tolerance=1e-3, window=5):
    for i in range(len(generation_fitness) - window):
        window_values = generation_fitness[i:i+window]
        if max(window_values) - min(window_values) < tolerance:
            return i + window
    return len(generation_fitness)

# %% [markdown]
# # GA + Local search

# %%
# File tổng hợp kết quả
summary_file = "results_summary_ga_goc.csv"
summary_cols = [
    "m", "total_distance", "fitness", "balance_metric", 
    "exec_time", "memory_current_MB", "memory_peak_MB", 
    "converged_gen", "convergence_speed"
]

# Tạo file rỗng (chỉ chạy lần đầu)
pd.DataFrame(columns=summary_cols).to_csv(summary_file, index=False)

for m in range(1, 4):
    print(f"\n=== Số người (m) = {m} ===")
    
    tracemalloc.start()
    start_time = time.time()
    
    total_distance, routes, fitness, fitness_per_generation = solve(distance_matrix, m)
    
    end_time = time.time()
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()

    exec_time = end_time - start_time

    # Độ dài từng tuyến
    route_distances = [
        sum(distance_matrix[r[i]][r[i+1]] for i in range(len(r)-1))
        for r in routes
    ]
    max_len = max(route_distances)
    min_len = min(route_distances)
    balance_metric = max_len - min_len

    # Phân tích hội tụ
    converged_gen = detect_convergence(fitness_per_generation)
    convergence_speed = (fitness_per_generation[0] - fitness_per_generation[-1]) / converged_gen if converged_gen else 0

    # In kết quả
    print(f"Tổng quãng đường: {total_distance:.2f}")
    print(f"Tuyến dài nhất (fitness): {fitness:.2f}")
    print(f"Chênh lệch giữa các tuyến (Balance metric): {balance_metric:.2f}")
    print(f"Thời gian thực thi: {exec_time:.4f} giây")
    print(f"Số vòng lặp để hội tụ: {converged_gen}")
    print(f"Tốc độ hội tụ: {convergence_speed:.4f} đơn vị/gen")
    print(f"Memory hiện tại: {current / 10**6:.2f} MB; Peak: {peak / 10**6:.2f} MB")

    for i, r in enumerate(routes):
        print(f" - Tuyến {i+1} ({route_distances[i]:.2f}): {r}")

    # === Lưu file tổng hợp ===
    row = {
        "m": m,
        "total_distance": total_distance,
        "fitness": fitness,
        "balance_metric": balance_metric,
        "exec_time": exec_time,
        "memory_current_MB": current / 10**6,
        "memory_peak_MB": peak / 10**6,
        "converged_gen": converged_gen,
        "convergence_speed": convergence_speed
    }
    pd.DataFrame([row]).to_csv(summary_file, mode="a", index=False, header=False)

    # === Lưu fitness_per_generation riêng ===
    fitness_file = f"ga_goc_fitness_m{m}.csv"
    pd.DataFrame({"generation": range(len(fitness_per_generation)),
                  "fitness": fitness_per_generation}).to_csv(fitness_file, index=False)

    # Vẽ biểu đồ fitness (tùy chọn)
    plt.figure(figsize=(8, 4))
    plt.plot(fitness_per_generation, marker='o', linestyle='-', color='blue')
    plt.title(f"Fitness qua các thế hệ (m = {m})")
    plt.xlabel("Thế hệ")
    plt.ylabel("Fitness (Tuyến dài nhất)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# === Số người (m) = 1 ===
# Chạy GA (m = 1):   0%|                                  | 0/300 [00:00<?, ?it/s]
# Chạy GA (m = 1):   1%|▎                         | 3/300 [00:00<01:17,  3.82it/s]
# [Gen   0] Best fitness: 1605.57 | Mutation rate: 0.18
# Chạy GA (m = 1):   7%|█▊                       | 22/300 [00:02<00:23, 11.86it/s]
# [Gen  20] Best fitness: 1326.70 | Mutation rate: 0.09
# Chạy GA (m = 1):  15%|███▋                     | 44/300 [00:04<00:18, 14.17it/s]
# [Gen  40] Best fitness: 1152.95 | Mutation rate: 0.07
# Chạy GA (m = 1):  21%|█████▏                   | 62/300 [00:05<00:24,  9.55it/s]
# [Gen  60] Best fitness: 1067.66 | Mutation rate: 0.09
# Chạy GA (m = 1):  27%|██████▊                  | 82/300 [00:08<00:27,  7.93it/s]
# [Gen  80] Best fitness: 1023.56 | Mutation rate: 0.08
# Chạy GA (m = 1):  34%|████████▏               | 102/300 [00:11<00:23,  8.49it/s]
# [Gen 100] Best fitness: 930.81 | Mutation rate: 0.05
# Chạy GA (m = 1):  40%|█████████▋              | 121/300 [00:13<00:26,  6.76it/s]
# [Gen 120] Best fitness: 882.64 | Mutation rate: 0.05
# Chạy GA (m = 1):  47%|███████████▎            | 142/300 [00:16<00:20,  7.74it/s]
# [Gen 140] Best fitness: 856.66 | Mutation rate: 0.06
# Chạy GA (m = 1):  54%|████████████▉           | 162/300 [00:18<00:16,  8.41it/s]
# [Gen 160] Best fitness: 837.52 | Mutation rate: 0.06
# Chạy GA (m = 1):  61%|██████████████▌         | 182/300 [00:21<00:14,  7.87it/s]
# [Gen 180] Best fitness: 818.13 | Mutation rate: 0.06
# Chạy GA (m = 1):  67%|████████████████▏       | 202/300 [00:23<00:10,  9.22it/s]
# [Gen 200] Best fitness: 804.76 | Mutation rate: 0.06
# Chạy GA (m = 1):  74%|█████████████████▊      | 222/300 [00:26<00:08,  8.90it/s]
# [Gen 220] Best fitness: 776.44 | Mutation rate: 0.06
# Chạy GA (m = 1):  81%|███████████████████▎    | 242/300 [00:28<00:06,  8.31it/s]
# [Gen 240] Best fitness: 760.17 | Mutation rate: 0.10
# Chạy GA (m = 1):  87%|████████████████████▉   | 262/300 [00:30<00:04,  8.82it/s]
# [Gen 260] Best fitness: 743.02 | Mutation rate: 0.11
# Chạy GA (m = 1):  94%|██████████████████████▌ | 282/300 [00:33<00:02,  7.95it/s]
# [Gen 280] Best fitness: 728.96 | Mutation rate: 0.08
# Chạy GA (m = 1): 100%|████████████████████████| 300/300 [00:35<00:00,  8.39it/s]
# [Gen 299] Best fitness: 718.22 | Mutation rate: 0.12
# Tổng quãng đường: 718.22
# Tuyến dài nhất (fitness): 718.22
# Chênh lệch giữa các tuyến (Balance metric): 0.00
# Thời gian thực thi: 36.6084 giây
# Số vòng lặp để hội tụ: 18
# Tốc độ hội tụ: 49.2972 đơn vị/gen
# Memory hiện tại: 8.96 MB; Peak: 9.62 MB
#  - Tuyến 1 (718.22): [0, 126, 40, 33, 112, 34, 113, 100, 82, 84, 123, 121, 39, 36, 25, 99, 96, 24, 28, 109, 117, 37, 38, 115, 103, 98, 91, 56, 60, 50, 57, 14, 69, 15, 101, 102, 23, 93, 20, 17, 8, 63, 7, 108, 27, 35, 122, 125, 118, 114, 32, 30, 104, 89, 90, 92, 97, 26, 94, 13, 48, 3, 4, 61, 66, 78, 12, 79, 80, 105, 21, 6, 76, 87, 111, 18, 59, 55, 1, 42, 41, 46, 53, 5, 67, 22, 75, 70, 49, 43, 44, 71, 77, 65, 2, 52, 72, 10, 9, 58, 51, 83, 85, 107, 74, 11, 106, 29, 31, 116, 110, 120, 19, 16, 73, 62, 81, 88, 86, 68, 64, 47, 54, 45, 95, 124, 119, 0]
# === Số người (m) = 2 ===
# Chạy GA (m = 2):   0%|                                  | 0/300 [00:00<?, ?it/s]
# [Gen   0] Best fitness: 853.58 | Mutation rate: 0.18
# Chạy GA (m = 2):   7%|█▊                       | 22/300 [00:03<00:36,  7.55it/s]
# [Gen  20] Best fitness: 686.57 | Mutation rate: 0.16
# Chạy GA (m = 2):  14%|███▍                     | 41/300 [00:06<00:50,  5.12it/s]
# [Gen  40] Best fitness: 645.63 | Mutation rate: 0.33
# Chạy GA (m = 2):  20%|█████                    | 61/300 [00:10<00:49,  4.84it/s]
# [Gen  60] Best fitness: 623.65 | Mutation rate: 0.50
# Chạy GA (m = 2):  27%|██████▊                  | 81/300 [00:14<00:38,  5.65it/s]
# [Gen  80] Best fitness: 605.96 | Mutation rate: 0.50
# Chạy GA (m = 2):  34%|████████                | 101/300 [00:17<00:33,  5.95it/s]
# [Gen 100] Best fitness: 582.77 | Mutation rate: 0.50
# Chạy GA (m = 2):  40%|█████████▋              | 121/300 [00:21<00:34,  5.13it/s]
# [Gen 120] Best fitness: 568.02 | Mutation rate: 0.50
# Chạy GA (m = 2):  47%|███████████▎            | 141/300 [00:25<00:29,  5.45it/s]
# [Gen 140] Best fitness: 553.04 | Mutation rate: 0.50
# Chạy GA (m = 2):  54%|████████████▉           | 161/300 [00:29<00:23,  5.83it/s]
# [Gen 160] Best fitness: 533.63 | Mutation rate: 0.50
# Chạy GA (m = 2):  60%|██████████████▍         | 181/300 [00:32<00:18,  6.29it/s]
# [Gen 180] Best fitness: 525.36 | Mutation rate: 0.44
# Chạy GA (m = 2):  67%|████████████████        | 201/300 [00:36<00:21,  4.59it/s]
# [Gen 200] Best fitness: 504.17 | Mutation rate: 0.33
# Chạy GA (m = 2):  74%|█████████████████▋      | 221/300 [00:39<00:14,  5.52it/s]
# [Gen 220] Best fitness: 492.79 | Mutation rate: 0.44
# Chạy GA (m = 2):  80%|███████████████████▎    | 241/300 [00:43<00:10,  5.47it/s]
# [Gen 240] Best fitness: 478.03 | Mutation rate: 0.45
# Chạy GA (m = 2):  87%|████████████████████▉   | 261/300 [00:46<00:06,  5.68it/s]
# [Gen 260] Best fitness: 461.90 | Mutation rate: 0.40
# Chạy GA (m = 2):  94%|██████████████████████▍ | 281/300 [00:50<00:03,  5.79it/s]
# [Gen 280] Best fitness: 451.07 | Mutation rate: 0.40
# Chạy GA (m = 2): 100%|████████████████████████| 300/300 [00:53<00:00,  5.56it/s]
# [Gen 299] Best fitness: 444.61 | Mutation rate: 0.50
# Tổng quãng đường: 888.06
# Tuyến dài nhất (fitness): 444.61
# Chênh lệch giữa các tuyến (Balance metric): 1.16
# Thời gian thực thi: 55.4365 giây
# Số vòng lặp để hội tụ: 10
# Tốc độ hội tụ: 40.8970 đơn vị/gen
# Memory hiện tại: 0.89 MB; Peak: 1.57 MB
#  - Tuyến 1 (444.61): [0, 57, 5, 59, 60, 100, 115, 123, 40, 126, 124, 119, 82, 3, 44, 6, 62, 43, 58, 51, 56, 83, 109, 90, 89, 68, 63, 66, 79, 71, 64, 8, 18, 98, 70, 67, 74, 107, 118, 122, 27, 73, 19, 105, 26, 99, 104, 29, 103, 78, 69, 48, 47, 4, 52, 46, 54, 10, 72, 112, 39, 121, 37, 84, 0]
#  - Tuyến 2 (443.45): [0, 49, 22, 106, 33, 114, 32, 31, 108, 111, 113, 76, 34, 23, 7, 9, 11, 91, 92, 77, 14, 35, 101, 102, 25, 110, 97, 12, 20, 93, 2, 45, 53, 50, 55, 17, 86, 13, 96, 24, 30, 117, 85, 80, 15, 87, 88, 75, 28, 36, 116, 94, 81, 65, 61, 42, 41, 1, 125, 21, 16, 120, 38, 95, 0]
# === Số người (m) = 3 ===
# Chạy GA (m = 3):   0%|                          | 1/300 [00:00<00:33,  9.03it/s]
# [Gen   0] Best fitness: 610.48 | Mutation rate: 0.18
# Chạy GA (m = 3):   7%|█▊                       | 22/300 [00:02<00:35,  7.85it/s]
# [Gen  20] Best fitness: 514.33 | Mutation rate: 0.13
# Chạy GA (m = 3):  14%|███▍                     | 41/300 [00:05<00:43,  5.93it/s]
# [Gen  40] Best fitness: 476.65 | Mutation rate: 0.22
# Chạy GA (m = 3):  20%|█████                    | 61/300 [00:09<00:45,  5.27it/s]
# [Gen  60] Best fitness: 460.61 | Mutation rate: 0.49
# Chạy GA (m = 3):  27%|██████▊                  | 81/300 [00:13<00:45,  4.83it/s]
# [Gen  80] Best fitness: 447.28 | Mutation rate: 0.45
# Chạy GA (m = 3):  34%|████████                | 101/300 [00:17<00:35,  5.62it/s]
# [Gen 100] Best fitness: 419.19 | Mutation rate: 0.50
# Chạy GA (m = 3):  40%|█████████▋              | 121/300 [00:21<00:32,  5.57it/s]
# [Gen 120] Best fitness: 414.53 | Mutation rate: 0.50
# Chạy GA (m = 3):  47%|███████████▎            | 141/300 [00:25<00:29,  5.42it/s]
# [Gen 140] Best fitness: 409.22 | Mutation rate: 0.50
# Chạy GA (m = 3):  54%|████████████▉           | 161/300 [00:29<00:25,  5.35it/s]
# [Gen 160] Best fitness: 401.38 | Mutation rate: 0.45
# Chạy GA (m = 3):  60%|██████████████▍         | 181/300 [00:32<00:20,  5.84it/s]
# [Gen 180] Best fitness: 392.71 | Mutation rate: 0.49
# Chạy GA (m = 3):  67%|████████████████        | 201/300 [00:36<00:17,  5.68it/s]
# [Gen 200] Best fitness: 380.30 | Mutation rate: 0.36
# Chạy GA (m = 3):  74%|█████████████████▋      | 221/300 [00:40<00:13,  5.95it/s]
# [Gen 220] Best fitness: 375.11 | Mutation rate: 0.41
# Chạy GA (m = 3):  80%|███████████████████▎    | 241/300 [00:44<00:12,  4.68it/s]
# [Gen 240] Best fitness: 369.63 | Mutation rate: 0.50
# Chạy GA (m = 3):  87%|████████████████████▉   | 261/300 [00:48<00:07,  4.99it/s]
# [Gen 260] Best fitness: 365.29 | Mutation rate: 0.50
# Chạy GA (m = 3):  94%|██████████████████████▌ | 282/300 [00:51<00:02,  6.66it/s]
# [Gen 280] Best fitness: 360.73 | Mutation rate: 0.32
# Chạy GA (m = 3): 100%|████████████████████████| 300/300 [00:54<00:00,  5.49it/s]
# [Gen 299] Best fitness: 357.26 | Mutation rate: 0.45
# Tổng quãng đường: 1071.30
# Tuyến dài nhất (fitness): 357.26
# Chênh lệch giữa các tuyến (Balance metric): 0.36
# Thời gian thực thi: 56.8687 giây
# Số vòng lặp để hội tụ: 22
# Tốc độ hội tụ: 11.5100 đơn vị/gen
# Memory hiện tại: 0.78 MB; Peak: 1.48 MB
#  - Tuyến 1 (357.14): [0, 82, 40, 124, 38, 108, 76, 71, 80, 14, 92, 97, 99, 51, 95, 83, 90, 6, 21, 35, 93, 116, 100, 28, 36, 85, 74, 67, 26, 29, 33, 115, 52, 68, 77, 50, 41, 42, 54, 63, 7, 3, 5, 0]
#  - Tuyến 2 (356.90): [0, 101, 120, 111, 96, 18, 72, 9, 11, 109, 126, 119, 75, 13, 81, 12, 69, 62, 91, 78, 24, 118, 31, 88, 65, 48, 43, 44, 47, 4, 89, 22, 98, 25, 104, 94, 23, 102, 110, 32, 39, 125, 10, 0]
#  - Tuyến 3 (357.26): [0, 57, 45, 60, 58, 46, 53, 59, 61, 2, 70, 66, 86, 8, 79, 17, 20, 106, 114, 30, 117, 107, 56, 55, 105, 19, 73, 122, 121, 103, 64, 87, 15, 27, 37, 123, 84, 16, 34, 112, 113, 49, 1, 0]

# %% [markdown]
# # GASA

# %% [markdown]
# # RLGA

# %% [markdown]
# # NSGA II
