# %% [markdown]
# # IMPORT LIBRARIES & DATA

# %%
# %pip install matplotlib numpy pandas

import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: numpy in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib numpy pandas

import sys
sys.path.append('../src')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from GA import solve
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: numpy in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (2.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vthuy\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vthuy\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
distance_df = pd.read_csv('../data/HN_distance_matrix.csv', index_col=0)
distance_matrix = distance_df.values

# Kiểm tra sơ bộ
print("Số thành phố:", distance_matrix.shape[0])
print("Ví dụ khoảng cách [0][1]:", distance_matrix[0][1])
# Out:
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 21.48

# %%
def detect_convergence(generation_fitness, tolerance=1e-3, window=5):
    for i in range(len(generation_fitness) - window):
        window_values = generation_fitness[i:i+window]
        if max(window_values) - min(window_values) < tolerance:
            return i + window
    return len(generation_fitness)

# %% [markdown]
# # GA + Local search

# %%
for m in range(1, 4):
    print(f"\n=== Số người (m) = {m} ===")
    
    start_time = time.time()
    total_distance, routes, fitness, fitness_per_generation = solve(distance_matrix, m)
    end_time = time.time()

    exec_time = end_time - start_time

    # Tính độ dài từng tuyến để đánh giá
    route_distances = [
        sum(distance_matrix[r[i]][r[i+1]] for i in range(len(r)-1))
        for r in routes
    ]
    max_len = max(route_distances)
    min_len = min(route_distances)
    balance_metric = max_len - min_len

    # Phân tích hội tụ
    converged_gen = detect_convergence(fitness_per_generation)
    convergence_speed = (fitness_per_generation[0] - fitness_per_generation[-1]) / converged_gen if converged_gen else 0

    # In kết quả
    print(f"Tổng quãng đường: {total_distance:.2f}")
    print(f"Tuyến dài nhất (fitness): {fitness:.2f}")
    print(f"Chênh lệch giữa các tuyến (Balance metric): {balance_metric:.2f}")
    print(f"Thời gian thực thi: {exec_time:.4f} giây")
    print(f"Số vòng lặp để hội tụ: {converged_gen}")
    print(f"Tốc độ hội tụ: {convergence_speed:.4f} đơn vị/gen")

    for i, r in enumerate(routes):
        print(f" - Tuyến {i+1} ({route_distances[i]:.2f}): {r}")

    # Vẽ biểu đồ fitness
    plt.figure(figsize=(8, 4))
    plt.plot(fitness_per_generation, marker='o', linestyle='-', color='blue')
    plt.title(f"Fitness qua các thế hệ (m = {m})")
    plt.xlabel("Thế hệ")
    plt.ylabel("Fitness (Tuyến dài nhất)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# === Số người (m) = 1 ===
# Chạy GA (m = 1):   0%|                                  | 0/300 [00:00<?, ?it/s]
# Chạy GA (m = 1):   0%|                          | 1/300 [00:04<21:22,  4.29s/it]
# [Gen   0] Best fitness: 1589.20
# Chạy GA (m = 1):   7%|█▊                       | 21/300 [00:09<00:59,  4.66it/s]
# [Gen  20] Best fitness: 1271.24
# Chạy GA (m = 1):  14%|███▍                     | 41/300 [00:13<00:48,  5.30it/s]
# [Gen  40] Best fitness: 1158.82
# Chạy GA (m = 1):  20%|█████                    | 61/300 [00:17<00:36,  6.51it/s]
# [Gen  60] Best fitness: 1133.92
# Chạy GA (m = 1):  27%|██████▊                  | 82/300 [00:20<00:29,  7.39it/s]
# [Gen  80] Best fitness: 1123.55
# Chạy GA (m = 1):  34%|████████                | 101/300 [00:22<00:31,  6.29it/s]
# [Gen 100] Best fitness: 1090.60
# Chạy GA (m = 1):  40%|█████████▋              | 121/300 [00:25<00:23,  7.76it/s]
# [Gen 120] Best fitness: 1090.60
# Chạy GA (m = 1):  47%|███████████▎            | 142/300 [00:28<00:22,  6.87it/s]
# [Gen 140] Best fitness: 1070.64
# Chạy GA (m = 1):  54%|████████████▉           | 161/300 [00:31<00:23,  5.97it/s]
# [Gen 160] Best fitness: 1043.73
# Chạy GA (m = 1):  60%|██████████████▍         | 181/300 [00:34<00:16,  7.32it/s]
# [Gen 180] Best fitness: 1031.07
# Chạy GA (m = 1):  67%|████████████████▏       | 202/300 [00:37<00:11,  8.62it/s]
# [Gen 200] Best fitness: 1031.07
# Chạy GA (m = 1):  74%|█████████████████▋      | 221/300 [00:40<00:14,  5.53it/s]
# [Gen 220] Best fitness: 1005.23
# Chạy GA (m = 1):  80%|███████████████████▎    | 241/300 [00:44<00:11,  5.14it/s]
# [Gen 240] Best fitness: 961.17
# Chạy GA (m = 1):  87%|████████████████████▉   | 262/300 [00:47<00:04,  7.76it/s]
# [Gen 260] Best fitness: 961.17
# Chạy GA (m = 1):  94%|██████████████████████▌ | 282/300 [00:49<00:02,  8.22it/s]
# [Gen 280] Best fitness: 949.87
# Chạy GA (m = 1): 100%|████████████████████████| 300/300 [00:51<00:00,  5.81it/s]
# [Gen 299] Best fitness: 908.14
# Tổng quãng đường: 908.14
# Tuyến dài nhất (fitness): 908.14
# Chênh lệch giữa các tuyến (Balance metric): 0.00
# Thời gian thực thi: 51.9005 giây
# Số vòng lặp để hội tụ: 39
# Tốc độ hội tụ: 17.4631 đơn vị/gen
#  - Tuyến 1 (908.14): [0, 40, 126, 124, 73, 19, 120, 34, 16, 105, 84, 82, 95, 109, 100, 115, 33, 106, 36, 39, 103, 28, 37, 121, 114, 122, 125, 118, 101, 77, 97, 93, 113, 80, 79, 15, 69, 62, 64, 76, 65, 92, 12, 102, 23, 78, 110, 17, 22, 30, 31, 75, 6, 71, 86, 88, 81, 5, 56, 50, 57, 49, 46, 51, 26, 116, 24, 18, 98, 72, 4, 61, 48, 3, 59, 53, 9, 41, 55, 14, 42, 2, 52, 54, 7, 25, 99, 108, 27, 70, 89, 32, 90, 20, 45, 8, 13, 21, 87, 96, 94, 68, 67, 85, 74, 44, 43, 47, 29, 35, 63, 66, 58, 1, 60, 11, 83, 10, 91, 107, 117, 104, 112, 111, 123, 38, 119, 0]
# === Số người (m) = 2 ===
# Chạy GA (m = 2):   0%|                          | 1/300 [00:00<00:44,  6.68it/s]
# [Gen   0] Best fitness: 850.09
# Chạy GA (m = 2):   7%|█▊                       | 22/300 [00:03<00:37,  7.47it/s]
# [Gen  20] Best fitness: 749.16
# Chạy GA (m = 2):  14%|███▌                     | 42/300 [00:06<00:34,  7.52it/s]
# [Gen  40] Best fitness: 703.69
# Chạy GA (m = 2):  21%|█████▏                   | 62/300 [00:08<00:28,  8.28it/s]
# [Gen  60] Best fitness: 646.97
# Chạy GA (m = 2):  27%|██████▊                  | 82/300 [00:11<00:26,  8.08it/s]
# [Gen  80] Best fitness: 625.88
# Chạy GA (m = 2):  34%|████████▏               | 102/300 [00:13<00:24,  8.08it/s]
# [Gen 100] Best fitness: 598.08
# Chạy GA (m = 2):  41%|█████████▊              | 122/300 [00:16<00:20,  8.50it/s]
# [Gen 120] Best fitness: 598.08
# Chạy GA (m = 2):  47%|███████████▎            | 142/300 [00:18<00:20,  7.53it/s]
# [Gen 140] Best fitness: 598.08
# Chạy GA (m = 2):  54%|████████████▉           | 161/300 [00:21<00:19,  7.06it/s]
# [Gen 160] Best fitness: 598.08
# Chạy GA (m = 2):  61%|██████████████▌         | 182/300 [00:24<00:15,  7.84it/s]
# [Gen 180] Best fitness: 597.42
# Chạy GA (m = 2):  67%|████████████████▏       | 202/300 [00:26<00:11,  8.70it/s]
# [Gen 200] Best fitness: 597.42
# Chạy GA (m = 2):  74%|█████████████████▊      | 222/300 [00:29<00:08,  9.16it/s]
# [Gen 220] Best fitness: 575.18
# Chạy GA (m = 2):  80%|███████████████████▎    | 241/300 [00:31<00:08,  7.25it/s]
# [Gen 240] Best fitness: 575.18
# Chạy GA (m = 2):  87%|████████████████████▉   | 261/300 [00:34<00:05,  6.69it/s]
# [Gen 260] Best fitness: 575.18
# Chạy GA (m = 2):  94%|██████████████████████▌ | 282/300 [00:37<00:02,  8.06it/s]
# [Gen 280] Best fitness: 575.18
# Chạy GA (m = 2): 100%|████████████████████████| 300/300 [00:39<00:00,  7.54it/s]
# [Gen 299] Best fitness: 575.18
# Tổng quãng đường: 1149.79
# Tuyến dài nhất (fitness): 575.18
# Chênh lệch giữa các tuyến (Balance metric): 0.57
# Thời gian thực thi: 40.1354 giây
# Số vòng lặp để hội tụ: 8
# Tốc độ hội tụ: 34.3637 đơn vị/gen
#  - Tuyến 1 (575.18): [0, 40, 126, 124, 85, 2, 80, 62, 5, 53, 79, 69, 71, 70, 77, 41, 59, 22, 64, 48, 44, 12, 36, 39, 28, 114, 113, 32, 94, 13, 66, 90, 91, 50, 58, 123, 38, 86, 118, 101, 55, 4, 47, 43, 14, 104, 21, 73, 19, 16, 6, 65, 63, 10, 125, 35, 26, 97, 102, 20, 98, 92, 99, 72, 0]
#  - Tuyến 2 (574.61): [0, 42, 83, 82, 84, 109, 52, 68, 3, 18, 106, 56, 49, 30, 25, 88, 45, 60, 57, 112, 78, 17, 111, 108, 110, 15, 105, 120, 23, 96, 8, 29, 100, 33, 107, 117, 121, 37, 122, 115, 1, 51, 95, 119, 103, 11, 24, 93, 87, 81, 67, 75, 76, 7, 9, 61, 54, 31, 27, 116, 34, 89, 74, 46, 0]
# === Số người (m) = 3 ===
# Chạy GA (m = 3):   0%|                                  | 0/300 [00:00<?, ?it/s]
# [Gen   0] Best fitness: 614.47
# Chạy GA (m = 3):   7%|█▊                       | 22/300 [00:02<00:30,  9.17it/s]
# [Gen  20] Best fitness: 512.08
# Chạy GA (m = 3):  14%|███▌                     | 42/300 [00:04<00:29,  8.87it/s]
# [Gen  40] Best fitness: 495.89
# Chạy GA (m = 3):  21%|█████▏                   | 62/300 [00:07<00:25,  9.42it/s]
# [Gen  60] Best fitness: 490.05
# Chạy GA (m = 3):  27%|██████▊                  | 82/300 [00:09<00:22,  9.66it/s]
# [Gen  80] Best fitness: 479.11
# Chạy GA (m = 3):  34%|████████▏               | 102/300 [00:11<00:23,  8.26it/s]
# [Gen 100] Best fitness: 479.11
# Chạy GA (m = 3):  41%|█████████▊              | 122/300 [00:13<00:16, 10.86it/s]
# [Gen 120] Best fitness: 461.35
# Chạy GA (m = 3):  47%|███████████▎            | 142/300 [00:15<00:16,  9.54it/s]
# [Gen 140] Best fitness: 460.02
# Chạy GA (m = 3):  54%|████████████▉           | 162/300 [00:17<00:13,  9.89it/s]
# [Gen 160] Best fitness: 460.02
# Chạy GA (m = 3):  61%|██████████████▌         | 182/300 [00:19<00:13,  8.89it/s]
# [Gen 180] Best fitness: 460.02
# Chạy GA (m = 3):  67%|████████████████        | 201/300 [00:22<00:12,  7.64it/s]
# [Gen 200] Best fitness: 460.02
# Chạy GA (m = 3):  74%|█████████████████▊      | 222/300 [00:25<00:11,  7.08it/s]
# [Gen 220] Best fitness: 455.66
# Chạy GA (m = 3):  81%|███████████████████▎    | 242/300 [00:27<00:06,  9.48it/s]
# [Gen 240] Best fitness: 455.66
# Chạy GA (m = 3):  87%|████████████████████▉   | 261/300 [00:29<00:04,  9.22it/s]
# [Gen 260] Best fitness: 455.66
# Chạy GA (m = 3):  94%|██████████████████████▌ | 282/300 [00:31<00:01,  9.10it/s]
# [Gen 280] Best fitness: 455.66
# Chạy GA (m = 3): 100%|████████████████████████| 300/300 [00:33<00:00,  8.90it/s]
# [Gen 299] Best fitness: 455.66
# Tổng quãng đường: 1342.81
# Tuyến dài nhất (fitness): 455.66
# Chênh lệch giữa các tuyến (Balance metric): 4.91
# Thời gian thực thi: 34.2215 giây
# Số vòng lặp để hội tụ: 26
# Tốc độ hội tụ: 6.1081 đơn vị/gen
#  - Tuyến 1 (449.43): [0, 16, 73, 55, 56, 106, 103, 28, 121, 39, 108, 62, 36, 13, 74, 41, 46, 51, 60, 96, 97, 5, 57, 88, 79, 87, 43, 44, 12, 117, 20, 123, 63, 61, 115, 10, 78, 113, 53, 42, 66, 98, 0]
#  - Tuyến 2 (444.52): [0, 84, 92, 18, 86, 70, 85, 118, 33, 24, 34, 120, 21, 107, 11, 75, 3, 65, 26, 58, 91, 110, 93, 94, 89, 52, 29, 100, 27, 25, 90, 101, 80, 23, 122, 32, 95, 126, 40, 124, 37, 114, 0]
#  - Tuyến 3 (448.86): [0, 76, 4, 8, 72, 30, 2, 109, 104, 45, 1, 99, 31, 125, 50, 14, 81, 67, 22, 71, 83, 38, 119, 82, 64, 6, 68, 48, 69, 102, 112, 19, 35, 15, 77, 105, 111, 116, 17, 54, 7, 49, 47, 59, 9, 0]

# %% [markdown]
# # GASA

# %% [markdown]
# # RLGA

# %% [markdown]
# # NSGA II
